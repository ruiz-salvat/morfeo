# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures

# %%
results = pd.read_csv('../Data/ResultData/wave_trend_results.csv')

# %%
results
# Out:
#        symbol   indicator           start_date             end_date  ob_level  \
# 0    ADA/USDT  wave_trend  2020-09-12 00:01:00  2020-09-12 23:59:00        53
# 1    ADA/USDT  wave_trend  2020-09-12 00:01:00  2020-09-12 23:59:00        53
# 2    ADA/USDT  wave_trend  2020-09-12 00:01:00  2020-09-12 23:59:00        53
# 3    ADA/USDT  wave_trend  2020-09-12 00:01:00  2020-09-12 23:59:00        53
# 4    ADA/USDT  wave_trend  2020-09-12 00:01:00  2020-09-12 23:59:00        53
# ..        ...         ...                  ...                  ...       ...
# 688  ADA/USDT  wave_trend  2020-09-18 00:00:00  2020-09-18 23:59:00        53
# 689  ADA/USDT  wave_trend  2020-09-18 00:00:00  2020-09-18 23:59:00        53
# 690  ADA/USDT  wave_trend  2020-09-18 00:00:00  2020-09-18 23:59:00        53
# 691  ADA/USDT  wave_trend  2020-09-18 00:00:00  2020-09-18 23:59:00        53
# 692  ADA/USDT  wave_trend  2020-09-18 00:00:00  2020-09-18 23:59:00        53
#
#      os_level      k      mean       std  skewness  kurtosis   entropy  \
# 0         -53  0.001  0.096585  0.000838 -0.070566 -0.741824  7.271666
# 1         -53  0.002  0.096585  0.000838 -0.070566 -0.741824  7.271666
# 2         -53  0.003  0.096585  0.000838 -0.070566 -0.741824  7.271666
# 3         -53  0.004  0.096585  0.000838 -0.070566 -0.741824  7.271666
# 4         -53  0.005  0.096585  0.000838 -0.070566 -0.741824  7.271666
# ..        ...    ...       ...       ...       ...       ...       ...
# 688       -53  0.095  0.092275  0.001107 -0.532186 -1.201226  7.272326
# 689       -53  0.096  0.092275  0.001107 -0.532186 -1.201226  7.272326
# 690       -53  0.097  0.092275  0.001107 -0.532186 -1.201226  7.272326
# 691       -53  0.098  0.092275  0.001107 -0.532186 -1.201226  7.272326
# 692       -53  0.099  0.092275  0.001107 -0.532186 -1.201226  7.272326
#
#      n_total_partitions  n_partitions  clean_gains
# 0                    10             5     0.532512
# 1                     8             4     0.399596
# 2                     7             3     0.399596
# 3                     7             4     0.254610
# 4                     7             4     0.254610
# ..                  ...           ...          ...
# 688                   0             0     0.000000
# 689                   0             0     0.000000
# 690                   0             0     0.000000
# 691                   0             0     0.000000
# 692                   0             0     0.000000
#
# [693 rows x 15 columns]

# %%
non_zero_results = results[results['clean_gains'] != 0]
plt.scatter(non_zero_results['k'], non_zero_results['clean_gains'])

# %%
poly = PolynomialFeatures(2)
poly.fit_transform()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-fa5cd4a4b5b0> in <module>
#       1 poly = PolynomialFeatures(2)
# ----> 2 poly.fit_transform()
#
# TypeError: fit_transform() missing 1 required positional argument: 'X'
